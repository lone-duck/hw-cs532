# %%
import json
import torch
from mh_within_gibbs import gibbs_sampling
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
f = open('graphs/1.json', 'rb')
g1 = json.load(f)
f.close()
f = open('graphs/2.json', 'rb')
g2 = json.load(f)
f.close()
f = open('graphs/3.json', 'rb')
g3 = json.load(f)
f.close()
f = open('graphs/4.json', 'rb')
g4 = json.load(f)
f.close()

# %%
# hamiltonian_monte_carlo
# TODO: clean up ENV behaviour so that all this sample_from_graph, jll, deterministic_eval
# can be imported

import torch 
from primitives import eval_env
from graph_utils import topological_sort
import copy

ENV = eval_env()


def hmc(graph, S, X0=None, T=20, epsilon=0.1, m=1, return_samples=False, report_acceptance_rate=False):
    # NOTE: for now, assume that len(X) is dimensionality of R
    # this may not be the case if element of X are vectors themselves
    
    if return_samples:
        samples = [None]*S
    if report_acceptance_rate:
        accepts = 0
    
    jlls = [None]*S
    ret_vals = [None]*S

    if X0 is None:
        X0 = sample_from_prior(graph)

    Xprev = X0
    Xdim = len(X0)

    ret_expr = graph[2]

    R_dist = torch.distributions.MultivariateNormal(torch.zeros(Xdim), m*torch.eye(Xdim))
    unif = torch.distributions.uniform.Uniform(0, 1)

    for s in range(S):
        # get a new R
        R_vals = R_dist.sample()
        R = dict(zip(Xprev.keys(), R_vals))
        # perform leapfrog integration WITH COPIES!
        """
        print("\n~~~~~~~ OUTER LOOP BEGIN~~~~~~~~")
        print('X')
        print(Xprev)
        print('R')
        print(R)
        """
        Xprime, Rprime = leapfrog(graph, copy.deepcopy(Xprev), copy.deepcopy(R), T, epsilon)
        """
        print('Xprime')
        print(Xprime)
        print('Rprime')
        print(Rprime)
        print("CHECK THIS SHIT OUT !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        print('X')
        print(Xprev)
        print('R')
        print(R)
        print("~~~~~~~~ OUTER LOOP END~~~~~~~~\n")
        """
        # compute acceptance values
        u = unif.sample()
        alpha = accept(graph, Xprev, R, Xprime, Rprime, m)
        print('alpha')
        print(alpha)
        # based on acceptance values, choose which X to keep
        if u < alpha:
            if report_acceptance_rate:
                accepts +=1
            Xkeep = Xprime
        else:
            Xkeep = Xprev

        # store appropriate things
        if return_samples:
            samples[s] = Xkeep
        ret_vals[s] = deterministic_evaluate(ret_expr, Xkeep)[0]
        jlls[s] = joint_log_likelihood(Xkeep, graph)

        # update Xprev
        Xprev = Xkeep

    if report_acceptance_rate:
        print("Acceptance rate: {}".format(accepts/S))

    if return_samples:
        return ret_vals, jlls, samples
    else:
        return ret_vals, jlls


def leapfrog(graph, X, R, T, epsilon):
    """
    print("\n~~~~~~~~ BEGIN LEAPFROG ~~~~~~~~~")
    print('X before')
    print(X)
    print('R before')
    print(R)
    """
    gradU = get_grad_U(graph, X)
    R = R_update(R, gradU, epsilon, half_step=True)

    for t in range(T-1):
        X = X_update(X, R, epsilon)
        gradU = get_grad_U(graph, X)
        R = R_update(R, gradU, epsilon)

    X = X_update(X, R, epsilon)
    gradU = get_grad_U(graph, X)
    R = R_update(R, gradU, epsilon, half_step=True)
    """
    print('X after')
    print(X)
    print('R after')
    print(R)
    print("~~~~~~~~ END LEAPFROG ~~~~~~~~~\n")    
    """
    return X, R


def get_grad_U(graph, X):

    P = graph[1]['P']
    Y = {k: torch.tensor(v).float() for k, v in graph[1]['Y'].items()}
    V = {**X, **Y}
    Vkeys = list(V.keys())
    U = 0
    for v in Vkeys:
        V[v].requires_grad=True
        if V[v].grad != None:
            V[v].grad.zero_()
    for v in Vkeys:
        expr = P[v][1]
        p_v, _ = deterministic_evaluate(expr, V)
        U += p_v.log_prob(V[v])

    U *= -1
    U.backward()
    gradU = {key: value.grad for key, value in X.items()}

    return gradU


def R_update(R, gradU, epsilon, half_step=False):
    
    keys = list(R.keys())
    if half_step:
        epsilon = 0.5*epsilon

    for r in keys:
        R[r] -= epsilon*gradU[r]

    return R


def X_update(X, R, epsilon):
    keys = list(X.keys())

    for x in keys:
        X[x].requires_grad = False
        X[x] += epsilon*R[x]

    return X


def accept(graph, X, R, Xprime, Rprime, m):
    """
    print("\n~~~~~~ INSIDE ACCEPT ~~~~~~")
    print('X')
    print(X)
    print('R')
    print(R)
    print('Xprime')
    print(Xprime)
    print('Rprime')
    print(Rprime)
    """
    K = 0
    for r in R.values():
        K += 0.5*r**2/m
    U = -1*joint_log_likelihood(X, graph)
    H = K + U

    Kprime = 0 
    for r in Rprime.values():
        Kprime += 0.5*r**2/m 
    Uprime = -1*joint_log_likelihood(Xprime, graph)
    Hprime = Kprime + Uprime
    """
    print('H')
    print(H)
    print('Hprime')
    print(Hprime)
    print("~~~~~~~~~ END ACCEPT ~~~~~~~~~~~~\n")
    """
    return torch.exp(-Hprime + H)

def sample_from_prior(graph):
    # get contents of graph
    fn_defs = graph[0]
    V = graph[1]['V']
    A = graph[1]['A']
    P = graph[1]['P']
    Y = graph[1]['Y']
    ret_vals = graph[2]
    
    # deal with fn_defs
    global ENV
    ENV = eval_env()
    for defn in fn_defs.items():
        f_name = defn[0]
        f_v_is = defn[1][1]
        f_expr = defn[1][2]
        ENV.update({f_name: (f_v_is, f_expr)})
    
    # get sorted V
    sorted_V = topological_sort(A, V)

    # compute each value in order
    l = {}
    for v in sorted_V:
        task, expr = P[v][0], P[v][1]
        if task == "sample*":
            dist, _ = deterministic_evaluate(expr, l)
            l.update({v: dist.sample()})

    return l


def joint_log_likelihood(X, graph):
    P = graph[1]['P']
    Y = {k: torch.tensor(v).float() for k, v in graph[1]['Y'].items()}
    V = {**X, **Y}
    Vkeys = list(V.keys())
    jll = 0

    for v in Vkeys:
        expr = P[v][1]
        p_v, _ = deterministic_evaluate(expr, V)
        jll += p_v.log_prob(V[v])

    return jll


def deterministic_evaluate(e, l, sig=None):
    # variable reference OR procedure OR just a string
    if isinstance(e, str):        
        # global procedures take precedence over locally defined vars
        if e in ENV:
            return ENV[e], sig
        elif e in l:
            return l[e], sig
        # could allow for hashmaps with string keys; for debugging setting this to fail
        else:
            assert False, "Unknown symbol: {}".format(e)
    # constant number
    elif isinstance(e, (int, float)):   
        return torch.tensor(float(e)), sig
    # if statements
    elif e[0] == 'if':
        (_, test, conseq, alt) = e
        exp = (conseq if deterministic_evaluate(test, l)[0] else alt)
        return deterministic_evaluate(exp, l)
    # let statements
    elif e[0] == 'let':
        # get symbol
        symbol = e[1][0]
        # get value of e1
        value, _ = deterministic_evaluate(e[1][1], l)
        # evaluate e2 with value 
        return deterministic_evaluate(e[2], {**l, symbol: value})
    # sample statement
    if e[0] == 'sample':
        dist = deterministic_evaluate(e[1], l)[0]
        # make sure it is a distribution object
        assert getattr(dist, '__module__', None).split('.')[:2] == ['torch', 'distributions']
        return dist.sample(), sig
    # obsere statements
    # TODO: change this, maybe in this hw or for hw3
    if e[0] == 'observe':
        dist = deterministic_evaluate(e[1], l)[0] # get dist
        y = deterministic_evaluate(e[2], l)[0]    # get observed value
        # make sure it is a distribution object
        assert getattr(dist, '__module__', None).split('.')[:2] == ['torch', 'distributions']
        # TODO: do something with observed value
        return dist.sample(), sig
    # procedure call, either primitive or user-defined
    else:
        result = deterministic_evaluate(e[0], l)
        proc, sig = result
        # primitives are functions
        if callable(proc):
            args = [deterministic_evaluate(arg, l)[0] for arg in e[1:]]
            result, sig = proc(*args), sig
            return result, sig
        # user defined functions are not
        else:
            # as written in algorithm 6
            v_is, e0 = proc 
            assert(len(v_is) == len(e[1:]))
            c_is = [deterministic_evaluate(arg, l)[0] for arg in e[1:]]
            l_proc = dict(zip(v_is, c_is))
            return deterministic_evaluate(e0, {**l, **l_proc})

# %%
ret_vals, jlls = hmc(g2, 1000, report_acceptance_rate=True)
# Out:
# alpha
# tensor(inf, grad_fn=<ExpBackward>)
# alpha
# tensor(6.1094, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0293, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9824, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0184, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7862, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2652, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9968, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9595, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9522, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1055, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8635, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1473, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8069, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2480, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9635, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8565, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0387, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1235, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9537, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9309, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8042, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6585, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4076, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8465, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1610, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9922, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9066, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0186, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1453, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6342, grad_fn=<ExpBackward>)
# alpha
# tensor(1.5119, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9528, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0770, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0168, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9448, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7085, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3864, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8576, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9413, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3423, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9125, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0098, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0689, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0173, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9720, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0264, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7738, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1281, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8493, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7890, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8817, grad_fn=<ExpBackward>)
# alpha
# tensor(1.9420, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7608, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0773, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8357, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4644, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5036, grad_fn=<ExpBackward>)
# alpha
# tensor(1.6341, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0480, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8130, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6431, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1833, grad_fn=<ExpBackward>)
# alpha
# tensor(1.8014, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9935, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9923, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9750, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9689, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0569, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8245, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0890, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9582, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0888, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0116, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0711, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9611, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7534, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3826, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5910, grad_fn=<ExpBackward>)
# alpha
# tensor(1.6294, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8219, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1574, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0812, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0092, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9773, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8286, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2319, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6113, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0828, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4595, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7830, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6142, grad_fn=<ExpBackward>)
# alpha
# tensor(2.1553, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6424, grad_fn=<ExpBackward>)
# alpha
# tensor(1.
grad_fn=<ExpBackward>)
# alpha
# tensor(1.0379, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8036, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9772, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7556, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2246, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1043, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9476, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0461, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9818, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0263, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9248, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9268, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9760, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1629, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6540, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0051, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8584, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1939, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7962, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1464, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8326, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3038, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8851, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1325, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9622, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8809, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1759, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0084, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7830, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6803, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3674, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0329, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0466, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7054, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4129, grad_fn=<ExpBackward>)
# alpha
# tensor(0.4886, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9098, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8591, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0633, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6237, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9602, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9120, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2502, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9958, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5757, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4105, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1079, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9664, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8864, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1886, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0915, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9776, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8472, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1982, grad_fn=<ExpBackward>)
# alpha
# tensor(0.3001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0067, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9540, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7661, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3760, grad_fn=<ExpBackward>)
# alpha
# tensor(0.4956, grad_fn=<ExpBackward>)
# alpha
# tensor(1.8475, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0219, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9320, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0882, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9542, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0909, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0072, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6338, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4125, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1163, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9408, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0454, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9927, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7791, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3079, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0065, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9897, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0076, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0034, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8464, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1386, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8733, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1814, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8515, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8906, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0078, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9657, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0384, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9091, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7053, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2809, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1710, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0255, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6022, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9870, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0258, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9443, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9391, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0247, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8720, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0789, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8885, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0914, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0187, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0243, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8947, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8941, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2596, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9140, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0768, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9959, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9855, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9041, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0381, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9821, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0039, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9248, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0797, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0041, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0113, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8876, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0725, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0235, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9826, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0451, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9632, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8011, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2630, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0047, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9932, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7644, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3389, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8779, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0913, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9893, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8737, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1831, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7883, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2707, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0195, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6776, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3309, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9454, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1132, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9512, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8383, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1544, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5877, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8597, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0373, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6390, grad_fn=<ExpBackward>)
# alpha
# tensor(1.8946, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7619, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7324, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.6655, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0329, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9948, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5518, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9635, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9568, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8704, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9460, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1395, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8964, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9575, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1288, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8762, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0348, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0820, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9959, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0685, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7511, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8355, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6106, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0113, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2966, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7382, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7659, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0163, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1118, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2049, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9466, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9137, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1462, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9357, grad_fn=<ExpBackward>)
# alpha
# tensor(0.3787, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9361, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1449, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9484, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0686, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8790, grad_fn=<ExpBackward>)
# alpha
# tensor(0.4148, grad_fn=<ExpBackward>)
# alpha
# tensor(2.6741, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5436, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2340, grad_fn=<ExpBackward>)
# alpha
# tensor(1.4891, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7512, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0234, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0039, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9566, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0454, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9724, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9643, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0520, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0105, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5959, grad_fn=<ExpBackward>)
# alpha
# tensor(0.4098, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8188, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9321, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2941, grad_fn=<ExpBackward>)
# alpha
# tensor(0.4078, grad_fn=<ExpBackward>)
# alpha
# tensor(1.6167, grad_fn=<ExpBackward>)
# alpha
# tensor(1.5322, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9852, grad_fn=<ExpBackward>)
# alpha
# tensor(0.3721, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9817, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9514, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9598, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9383, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1058, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0973, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9448, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8238, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2374, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(0.3587, grad_fn=<ExpBackward>)
# alpha
# tensor(2.7911, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0156, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7951, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2703, grad_fn=<ExpBackward>)
# alpha
# tensor(0.5894, grad_fn=<ExpBackward>)
# alpha
# tensor(1.5024, grad_fn=<ExpBackward>)
# alpha
# tensor(1.1421, grad_fn=<ExpBackward>)
# alpha
# tensor(0.6966, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3399, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0118, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0574, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8537, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8710, grad_fn=<ExpBackward>)
# alpha
# tensor(1.3229, grad_fn=<ExpBackward>)
# alpha
# tensor(0.7282, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0752, grad_fn=<ExpBackward>)
# alpha
# tensor(1.2687, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9445, grad_fn=<ExpBackward>)
# alpha
# tensor(0.8162, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0035, grad_fn=<ExpBackward>)
# Acceptance rate: 0.926

# %%
ret_vals = torch.stack(ret_vals)

# %%
torch.mean(ret_vals, dim=0)
# Out:
# tensor([ 2.1446, -0.4868], grad_fn=<MeanBackward1>)

# %%
ret_vals, jlls = hmc(g1, 1000, report_acceptance_rate=True)
# Out:
# alpha
# tensor(1.0790, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0420, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0070, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9972, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9954, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0046, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9953, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0070, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9933, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0048, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0040, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9962, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0031, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9962, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9956, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9919, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0088, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9883, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0100, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0024, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9965, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0054, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9959, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0041, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9907, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0065, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0031, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9906, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0095, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9971, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0025, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9983, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9956, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0031, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9965, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0035, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0039, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9935, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0027, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9948, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0055, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9949, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0038, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9981, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0035, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9971, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0031, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9968, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0046, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0044, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9972, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9911, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0104, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9983, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9970, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0041, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1., grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9964, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9882, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0102, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9959, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0028, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9953, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0070, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9853, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0088, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0040, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9959, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0065, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9970, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9970, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0055, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9972, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9949, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0046, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9951, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0034, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9981, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0025, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0043, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9958, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9939, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0050, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9965, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0038, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0029, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9902, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0039, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0024, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9952, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0065, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0035, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9945, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0045, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9931, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0047, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0027, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9983, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9945, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9955, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0029, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9954, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0034, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9968, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9966, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9962, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0059, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9894, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0048, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0063, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9965, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9793, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0176, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0079, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9966, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9956, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0049, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9981, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0025, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9966, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0047, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9962, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0042, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9972, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0030, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9964, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0043, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9939, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0046, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9986, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0024, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0033, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9976, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0024, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0034, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9981, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9977, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9946, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0075, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9952, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0047, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9983, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0027, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9970, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0031, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0021, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0025, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9981, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0026, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9925, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0061, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0033, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9969, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9964, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9928, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0069, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0061, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0015, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1., grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0011, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0005, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9982, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0018, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0012, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9960, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9983, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0033, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0020, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9973, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9968, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0010, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9979, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9996, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9985, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9987, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0037, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9993, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0004, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0001, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9978, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0013, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9970, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0023, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9988, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9963, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9994, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9950, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0032, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0036, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9949, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9989, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0017, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0051, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0029, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9957, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0046, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9965, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0016, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0019, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9957, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9967, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0076, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0009, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9991, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9958, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9974, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0022, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0027, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0028, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9995, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0008, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9998, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9980, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0007, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9990, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0042, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9992, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0003, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9975, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0029, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0002, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0000, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9997, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0006, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9999, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9984, grad_fn=<ExpBackward>)
# alpha
# tensor(1.0014, grad_fn=<ExpBackward>)
# alpha
# tensor(0.9961, grad_fn=<ExpBackward>)
# Acceptance rate: 1.0

# %%
ret_vals = torch.stack(ret_vals)

# %%
torch.mean(ret_vals)
# Out:
# tensor(7.2236, grad_fn=<MeanBackward0>)

# %%
torch.std(ret_vals)**2
# Out:
# tensor(0.8916, grad_fn=<PowBackward0>)

# %%
jlls = torch.stack(jlls)

# %%
plt.plot(jlls.detach().numpy())
